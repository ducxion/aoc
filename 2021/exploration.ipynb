# %%
# Day 1
import numpy as np
import pandas as pd

# %%
# Test
test = [
199,
200,
208,
210,
200,
207,
240,
269,
260,
263,
]

# %%
array = np.loadtxt("input/day2.input", dtype=str)

# %%
array
# Out:
# array([['forward', '2'],
#        ['forward', '5'],
#        ['forward', '5'],
#        ...,
#        ['forward', '9'],
#        ['up', '3'],
#        ['forward', '6']], dtype='<U7')

# %%
axis = array[:,0].astype(str)
val = array[:,1].astype(int)

# %%
depth, position, aim = 0,0,0
for i in range(axis.shape[0]):
    if axis[i] == "up":
        aim -= val[i]
    elif axis[i] == "down":
        aim += val[i]
    else:
        position += val[i]
        depth += (aim * val[i])

# %%
for i in range(axis.shape[0]):

# %%
val[np.where(axis == "up")] *= -1

# %%
val[np.where(axis == "forward")] = 0

# %%
aim = np.cumsum(val)

# %%
np.cumsum(val[np.where(axis=="forward")] * aim[np.where(axis=="forward")])[-1]
# Out:
# 895269

# %%
aim
# Out:
# array([  0,   0,   0,   4,   4,   5,   5,   5,  14,  16,  16,  16,  25,
#         27,  27,  25,  25,  19,  19,  19,  14,  14,  23,  23,  23,  23,
#         23,  23,  23,  23,  25,  25,  29,  35,  41,  41,  41,  38,  33,
#         38,  41,  39,  46,  48,  48,  48,  47,  54,  54,  61,  67,  67,
#         61,  61,  70,  67,  73,  74,  74,  73,  74,  71,  64,  64,  69,
#         69,  69,  78,  70,  70,  74,  73,  73,  73,  75,  75,  77,  82,
#         84,  83,  88,  88,  88,  88,  88,  88,  89,  89,  96,  89,  92,
#         93, 100, 104, 104, 104, 113, 118, 118, 111, 113, 112, 112, 112,
#        119, 122, 122, 118, 118, 110, 119, 123, 123, 123, 126, 131, 135,
#        144, 152, 152, 155, 156, 165, 171, 171, 171, 166, 166, 166, 175,
#        168, 166, 166, 166, 166, 158, 167, 169, 169, 175, 175, 166, 159,
#        167, 166, 166, 166, 175, 175, 177, 178, 175, 175, 178, 182, 191,
#        183, 175, 175, 168, 168, 168, 166, 158, 158, 164, 164, 164, 171,
# ...

# %%
axis = array[:,0].astype(str)
val = array[:,1].astype(int)

# %%
val[np.where(axis == 'up')] *= -1

# %%
val[posix] = 0

# %%
posix = np.where(axis=='forward')
position = np.sum(val[posix])
depth = val[posix] * aim[posix

# %%
(val[posix] * aim[posix])[-1]
# Out:
# 5100

# %%
pos_dict = dict()
for axis in ['forward', 'down', 'up']:
    index = np.where(array[:,0] == axis)
    pos_dict[axis] = np.sum(array[index,1].astype(int))

# %%
position
# Out:
# 2073

# %%
array[np.where(array[:,0] == 'down'),1].astype(int) * -1
# Out:
# array([[-4, -1, -9, -2, -9, -2, -9, -2, -4, -6, -6, -5, -3, -7, -2, -7,
#         -7, -6, -9, -6, -1, -1, -5, -9, -4, -2, -2, -5, -2, -5, -1, -7,
#         -3, -1, -7, -4, -9, -5, -2, -7, -3, -9, -4, -3, -5, -4, -9, -8,
#         -3, -1, -9, -6, -9, -9, -2, -6, -8, -9, -2, -1, -3, -4, -9, -6,
#         -7, -2, -3, -6, -8, -7, -6, -2, -3, -7, -6, -6, -6, -3, -9, -3,
#         -3, -3, -3, -1, -1, -7, -7, -7, -7, -7, -6, -6, -8, -4, -7, -6,
#         -9, -7, -6, -3, -4, -1, -1, -6, -4, -7, -4, -8, -6, -7, -1, -6,
#         -8, -8, -6, -9, -6, -8, -5, -8, -3, -7, -4, -8, -8, -3, -2, -2,
#         -1, -7, -9, -3, -5, -2, -6, -7, -4, -9, -2, -2, -6, -3, -6, -6,
#         -9, -6, -3, -9, -6, -8, -3, -7, -2, -6, -3, -7, -6, -3, -2, -2,
#         -2, -3, -4, -7, -3, -3, -3, -9, -6, -7, -4, -4, -9, -7, -1, -9,
#         -6, -8, -3, -6, -7, -9, -1, -3, -6, -7, -2, -1, -1, -8, -1, -6,
#         -2, -1, -7, -8, -6, -2, -5, -1, -8, -3, -6, -1, -1, -8, -8, -2,
# ...

# %%
dtype = [('axis', 'str'), ('val', 'int')]
array2 = np.array(array, dtype=dtype)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_5740/3657322398.py in <module>
#       1 dtype = [('axis', 'str'), ('val', 'int')]
# ----> 2 array2 = np.array(array, dtype=dtype)
#
# ValueError: invalid literal for int() with base 10: 'forward'

# %%
array.dtype.descr = [('', str),('', int)]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_5740/3274981896.py in <module>
# ----> 1 array.dtype.descr = [('', str),('', int)]
#
# AttributeError: attribute 'descr' of 'numpy.dtype' objects is not writable
